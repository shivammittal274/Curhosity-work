# %%
import numpy as np
import pandas as pd

data=pd.read_excel("2020 nifty 5min data.xlsx")

# %%
data=data[2:]
data
# Out:
#        Unnamed: 0                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 2             4.0  202001010.38541666666666712212.45   20200101   09:15:00
# 3             5.0   202001010.38888888888888912215.9   20200101   09:20:00
# 4             6.0  202001010.39236111111111112222.05   20200101   09:25:00
# 5             7.0   202001010.39583333333333312212.8   20200101   09:30:00
# 6             8.0  202001010.39930555555555612208.35   20200101   09:35:00
# ...           ...                                ...        ...        ...
# 14150     14152.0   202009300.62847222222222211259.8   20200930   15:05:00
# 14151     14153.0   202009300.63194444444444411247.4   20200930   15:10:00
# 14152     14154.0  202009300.63541666666666711248.25   20200930   15:15:00
# 14153     14155.0  202009300.63888888888888911231.15   20200930   15:20:00
# 14154     14156.0   202009300.64236111111111111226.3   20200930   15:25:00
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
pivots=[]
index=[]
for i in range(len(data)-12):
    tpData=data["Unnamed: 7"][i:i+11]
    tpData=tpData.tolist() 
#     print(tpData.shape)
#     print(type(tpData))
    currentMax=max(tpData,default=0)
    if(tpData.index(currentMax)==6):
#         index.append(i+8)
        pivots.append(currentMax)
#     print(i)

# %%
print(str(pivots))
# len(index)
# Out:
# [12190.15, 12182.8, 12192.25, 12224.1, 12234.6, 12266.75, 12265.3, 12286.7, 12264.65, 12248.4, 12231.35, 12237, 12231.6, 12096.25, 12036.7, 12021.15, 12008.35, 12148.5, 12087.45, 12079.35, 12086.15, 12043.5, 12051.6, 12064.65, 11968.4, 12010.2, 12007.55, 12162.25, 12185.3, 12194.1, 12213, 12208.3, 12220, 12255.65, 12281.5, 12307.85, 12308.95, 12261.25, 12331.35, 12331.05, 12334.9, 12334.4, 12332.3, 12347.1, 12343.3, 12339.2, 12345.4, 12367.4, 12304.85, 12309.6, 12308.5, 12302.75, 12384.7, 12337.5, 12341, 12354.95, 12366.25, 12360.2, 12377.95, 12379.55, 12379.85, 12360.8, 12365.65, 12357.95, 12399.4, 12307.65, 12298.35, 12271.5, 12221.05, 12189.6, 12208.85, 12198, 12197.45, 12212.1, 12150.55, 12138.15, 12141.65, 12122.95, 12170.35, 12180.3, 12171.9, 12186.45, 12216.65, 12241.05, 12231.2, 12232.9, 12263.5, 12267.25, 12216.25, 12206.9, 12162.2, 12126.2, 12125.25, 12136.4, 12136.75, 12151.75, 12158.25, 12159.4, 12158.55, 12166.5, 12134.05, 12084.95, 12067.05, 12042.75, 12055.15, 12081.2,
# ...

# %%
data["Unnamed: 7"][0:11].tolist()
# Out:
# [12212.45,
#  12215.9,
#  12222.05,
#  12212.8,
#  12208.35,
#  12202.75,
#  12195.6,
#  12199.9,
#  12200.6,
#  12195.2,
#  12186.45]

# %%
# data["Unnamed: 10"].value_counts()
data.shape
# Out:
# (14153, 11)
